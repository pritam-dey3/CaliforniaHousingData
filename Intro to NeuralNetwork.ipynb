# %% [markdown]
# <a href="https://colab.research.google.com/github/pritam3339/CaliforniaHousingData/blob/master/Intro%20to%20NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('sample_data/mnist_train_small.csv', header=None)
test = pd.read_csv('sample_data/mnist_test.csv', header=None)
labels = data[0]
data = data.drop(0, axis=1)
test_labels = test[0]
test = test.drop(0, axis=1)

# %%
model = keras.models.Sequential([
            keras.layers.Dense(100, activation='relu', input_shape=(784,)),
            keras.layers.Dense(100, activation='relu'),
            keras.layers.Dense(10, activation='softmax'),
])

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
hist = model.fit(data.to_numpy(), labels.to_numpy(), epochs=20, validation_data=(test.to_numpy(), test_labels.to_numpy()))
# Out:
# Epoch 1/20
# 625/625 [==============================] - 2s 3ms/step - loss: 4.2228 - accuracy: 0.8231 - val_loss: 1.2954 - val_accuracy: 0.8858
# Epoch 2/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.9298 - accuracy: 0.8968 - val_loss: 0.9467 - val_accuracy: 0.8998
# Epoch 3/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5889 - accuracy: 0.9194 - val_loss: 0.9385 - val_accuracy: 0.8959
# Epoch 4/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4643 - accuracy: 0.9320 - val_loss: 0.8723 - val_accuracy: 0.8977
# Epoch 5/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3976 - accuracy: 0.9362 - val_loss: 0.7411 - val_accuracy: 0.9096
# Epoch 6/20
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3376 - accuracy: 0.9434 - val_loss: 0.6836 - val_accuracy: 0.9191
# Epoch 7/20
# ...

# %%
import matplotlib.pyplot as plt

pd.DataFrame(hist.history).plot()
plt.gca().set_ylim(0,1)
# Out:
# (0.0, 1.0)
